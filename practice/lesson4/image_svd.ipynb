# %%
from PIL import Image
import numpy as np
from scipy.linalg import svd
import matplotlib.pylab as plt

def get_image_feature(s, k):
    s_temp = np.zeros(s.shape[0])
    s_temp[:k] = s[:k]
    s = s_temp * np.identity(s.shape[0])
    print(s.shape)
    temp = np.dot(p,s)
    temp = np.dot(temp,q)
    plt.imshow(temp, cmap=plt.cm.gray, interpolation='nearest')
    plt.show()
    
image = Image.open('./huangw3.jpg').convert('L')
A = np.array(image)
plt.imshow(A, cmap=plt.cm.gray, interpolation='nearest')
plt.show()
print(A.shape)
p,s,q = svd(A, full_matrices = False)
print(p.shape)
print(s.shape)
print(q.shape)
get_image_feature(s, int(s.shape[0] * 0.01))
get_image_feature(s, int(s.shape[0] * 0.1))
get_image_feature(s, int(s.shape[0] * 0.5))
# Out:
# (375, 500)
# (375, 375)
# (375,)
# (375, 500)
# (375, 375)
# (375, 375)
# (375, 375)
